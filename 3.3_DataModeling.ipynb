# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv(r"Data\train_data_binned.csv")
test_data = pd.read_csv(r"Data\test_data_binned.csv")

# %%
train_data.min()
# Out:
# Unnamed: 0.1      0.0
# Unnamed: 0        0.0
# id                0.0
# Feature 1         0.2
# Feature 2         0.0
# Feature 3         0.0
# Feature 4         0.0
# Feature 5         0.0
# Feature 6         0.0
# Feature 7         0.0
# Feature 8         0.0
# Feature 9         0.0
# Feature 10        0.0
# Feature 11        0.0
# Feature 12        0.0
# Feature 13        0.0
# Feature 14        0.0
# Feature 15        0.0
# Feature 16        0.0
# Feature 17        0.0
# Feature 18        0.0
# Feature 19        0.0
# Feature 20        0.0
# Feature 21        0.0
# Feature 22       52.7
# Feature 23       51.0
# Feature  24       0.0
# Feature 25        0.0
# Feature 26        0.0
# price           326.0
# bin               1.0
# dtype: float64

# %%
col = list(train_data.columns)
col.remove('Unnamed: 0')
col.remove('Unnamed: 0.1')
col.remove('id')
col.remove('price')
col.remove('bin')
#col.remove('Feature 2')
#col.remove('Feature 3')
#col.remove('Feature 4')
#col.remove('Feature 5')
#col.remove('Feature 6')
#col.remove('Feature 11')
#col.remove('Feature 15')
#col.remove('Feature 18')
#col.remove('Feature 19')
#col.remove('Feature 20')
#col.remove('Feature 21')
col
# Out:
# ['Feature 1',
#  'Feature 2',
#  'Feature 3',
#  'Feature 4',
#  'Feature 5',
#  'Feature 6',
#  'Feature 7',
#  'Feature 8',
#  'Feature 9',
#  'Feature 10',
#  'Feature 11',
#  'Feature 12',
#  'Feature 13',
#  'Feature 14',
#  'Feature 15',
#  'Feature 16',
#  'Feature 17',
#  'Feature 18',
#  'Feature 19',
#  'Feature 20',
#  'Feature 21',
#  'Feature 22',
#  'Feature 23',
#  'Feature  24',
#  'Feature 25',
#  'Feature 26']

# %%
train_data['train-test'] = "train"
test_data['train-test'] = "test"

# %%
combined_df = pd.concat([train_data,test_data]).fillna('TBC')

# %%
scaler = MinMaxScaler()

#combined_df["Feature 1"] = scaler.fit_transform(np.array(combined_df["Feature 1"]).reshape(-1,1))
combined_df["Feature 22"] = scaler.fit_transform(np.array(combined_df["Feature 22"]).reshape(-1,1))
combined_df["Feature 23"] = scaler.fit_transform(np.array(combined_df["Feature 23"]).reshape(-1,1))
combined_df["Feature  24"] = scaler.fit_transform(np.array(combined_df["Feature  24"]).reshape(-1,1))
combined_df["Feature 25"] = scaler.fit_transform(np.array(combined_df["Feature 25"]).reshape(-1,1))
combined_df["Feature 26"] = scaler.fit_transform(np.array(combined_df["Feature 26"]).reshape(-1,1))

# %%
df_group = combined_df.groupby(['train-test'])
train_data = df_group.get_group('train')
test_data = df_group.get_group('test')

# %%
train_data.min()
# Out:
# Unnamed: 0.1           0
# Unnamed: 0             0
# id                     0
# Feature 1            0.2
# Feature 2              0
# Feature 3              0
# Feature 4              0
# Feature 5              0
# Feature 6              0
# Feature 7              0
# Feature 8              0
# Feature 9              0
# Feature 10             0
# Feature 11             0
# Feature 12             0
# Feature 13             0
# Feature 14             0
# Feature 15             0
# Feature 16             0
# Feature 17             0
# Feature 18             0
# Feature 19             0
# Feature 20             0
# Feature 21             0
# Feature 22      0.030769
# Feature 23      0.066667
# Feature  24          0.0
# Feature 25           0.0
# Feature 26           0.0
# price              326.0
# bin                    1
# train-test         train
# dtype: object

# %%
train_data = train_data.drop('train-test',axis=1)
test_data = test_data.drop('train-test',axis=1)

# %%
test_data = test_data.drop('price',axis = 1)

# %%
train_data
# Out:
#         Unnamed: 0.1  Unnamed: 0      id  Feature 1  Feature 2  Feature 3
# 0                  0      143728  143728       0.53          0          0  \
# 1                  1       52657   52657       0.50          0          1
# 2                  2      124407  124407       2.03          0          0
# 3                  3       45535   45535       0.33          0          0
# 4                  4      178894  178894       0.90          0          1
# ...              ...         ...     ...        ...        ...        ...
# 135496        135496       34345   34345       0.70          0          1
# 135497        135497        9899    9899       0.33          0          0
# 135498        135498      142454  142454       2.03          0          0
# 135499        135499      129168  129168       0.73          0          1
# 135500        135500       10470   10470       1.72          0          0
#
#         Feature 4  Feature 5  Feature 6  Feature 7  ...  Feature 19
# ...

# %%
from xgboost import XGBRegressor

# %%
xg = XGBRegressor(n_estimators=300, learning_rate=0.05,subsample = 0.5)

# %%
train_data_bin_1 = train_data.loc[train_data['bin'] == 1]
train_data_bin_1_input = train_data_bin_1[col]
train_data_bin_1_target = train_data_bin_1['price']

# %%
train_data_bin_1_input.min()
# Out:
# Feature 1      0.200000
# Feature 2      0.000000
# Feature 3      0.000000
# Feature 4      0.000000
# Feature 5      0.000000
# Feature 6      0.000000
# Feature 7      0.000000
# Feature 8      0.000000
# Feature 9      0.000000
# Feature 10     0.000000
# Feature 11     0.000000
# Feature 12     0.000000
# Feature 13     0.000000
# Feature 14     0.000000
# Feature 15     0.000000
# Feature 16     0.000000
# Feature 17     0.000000
# Feature 18     0.000000
# Feature 19     0.000000
# Feature 20     0.000000
# Feature 21     0.000000
# Feature 22     0.225641
# Feature 23     0.100000
# Feature  24    0.000000
# Feature 25     0.000000
# Feature 26     0.000000
# dtype: float64

# %%
X_train ,X_test,y_train,y_test = train_test_split(train_data_bin_1_input,train_data_bin_1_target, test_size=0.2, random_state=42)

# %%
X_train.min()
# Out:
# Feature 1      0.200000
# Feature 2      0.000000
# Feature 3      0.000000
# Feature 4      0.000000
# Feature 5      0.000000
# Feature 6      0.000000
# Feature 7      0.000000
# Feature 8      0.000000
# Feature 9      0.000000
# Feature 10     0.000000
# Feature 11     0.000000
# Feature 12     0.000000
# Feature 13     0.000000
# Feature 14     0.000000
# Feature 15     0.000000
# Feature 16     0.000000
# Feature 17     0.000000
# Feature 18     0.000000
# Feature 19     0.000000
# Feature 20     0.000000
# Feature 21     0.000000
# Feature 22     0.235897
# Feature 23     0.100000
# Feature  24    0.000000
# Feature 25     0.000000
# Feature 26     0.000000
# dtype: float64

# %%
X_train
y_train_unit  = y_train/X_train['Feature 1']

# %%
y_train_unit
# Out:
# 88687      2889.74359
# 44060     2586.666667
# 23009         2618.75
# 132614    2272.727273
# 117721    3060.606061
#              ...
# 33518          2500.0
# 132922         1800.0
# 113314    3038.709677
# 2581      1980.952381
# 46954     1538.235294
# Length: 36448, dtype: object

# %%
X_train_new = X_train.drop('Feature 1',axis = 1)

# %%
xg.fit(X_train_new, y_train_unit)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
X_test_new = X_test.drop('Feature 1',axis = 1)

# %%
X_test_new
# Out:
#         Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  Feature 7
# 5435            0          0          1          0          0          0  \
# 128347          0          0          0          1          0          0
# 77592           0          0          1          0          0          0
# 108254          0          0          1          0          0          0
# 78010           0          0          1          0          0          1
# ...           ...        ...        ...        ...        ...        ...
# 54086           0          0          1          0          0          0
# 77760           0          0          1          0          0          0
# 120711          0          0          1          0          0          0
# 41266           0          0          0          1          0          0
# 104480          0          0          1          0          0          1
#
#         Feature 8  Feature 9  Feature 10  Feature 11  ...  Feature 17
# ...

# %%
y_pred = xg.predict(X_test_new)

# %%
y_pred = y_pred*(X_test['Feature 1'])

# %%
bin1 = {}

bin1['Mean Absolute Error:'] =  metrics.mean_absolute_error(y_test, y_pred)  
bin1['Mean Squared Error:'] =  metrics.mean_squared_error(y_test, y_pred) 
bin1['Root Mean Squared Error:'] = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
bin1
# Out:
# {'Mean Absolute Error:': 65.80627320072755,
#  'Mean Squared Error:': 7188.904304488706,
#  'Root Mean Squared Error:': 84.78740652059541}

# %%
test_data_bin_1 = test_data.loc[test_data['bin'] == 1]
test_data_bin_1_input = test_data_bin_1[col]

# %%
test_data_bin_1_input
# Out:
#        Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 3           0.30          0          0          0          0          1  \
# 4           0.23          0          0          0          1          0
# 5           0.30          0          0          1          0          0
# 8           0.42          0          0          1          0          0
# 11          0.32          0          0          0          1          0
# ...          ...        ...        ...        ...        ...        ...
# 58051       0.42          0          0          0          0          1
# 58053       0.30          0          0          1          0          0
# 58056       0.32          0          0          1          0          0
# 58060       0.31          0          0          1          0          0
# 58063       0.30          0          0          1          0          0
#
#        Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 17
# ...

# %%
train_data_bin_1_target_new = train_data_bin_1_target/train_data_bin_1_input['Feature 1']

# %%
train_data_bin_1_input_new  = train_data_bin_1_input.drop('Feature 1',axis = 1)

# %%
xg.fit(train_data_bin_1_input_new,train_data_bin_1_target_new)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_data_bin_1_input_new = test_data_bin_1_input.drop('Feature 1',axis = 1)

# %%
test_pred_bin_1 = xg.predict(test_data_bin_1_input_new)

# %%
test_pred_bin_1_new = test_pred_bin_1*(test_data_bin_1_input['Feature 1'])

# %%
test_pred_bin_1_new
# Out:
# 3         674.197852
# 4         532.824873
# 5         699.757031
# 8        1055.268662
# 11        645.177148
#             ...
# 58051     859.401467
# 58053     868.110645
# 58056     862.352500
# 58060     832.318364
# 58063     719.191040
# Name: Feature 1, Length: 19455, dtype: float64

# %%
price_pred_bin_1 = pd.DataFrame({'id': test_data_bin_1.id, 'Price': test_pred_bin_1_new})

# %%
xg2 = XGBRegressor(n_estimators=300, learning_rate=0.05,subsample = 0.5)

# %%
train_data_bin_2 = train_data.loc[train_data['bin'] == 2]
train_data_bin_2_input = train_data_bin_2[col]
train_data_bin_2_target = train_data_bin_2['price']

# %%
X_train ,X_test,y_train,y_test = train_test_split(train_data_bin_2_input,train_data_bin_2_target, test_size=0.2, random_state=42)

# %%
X_train
y_train_unit  = y_train/X_train['Feature 1']

# %%
X_train_new = X_train.drop('Feature 1',axis = 1)

# %%
xg2.fit(X_train_new, y_train_unit)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
X_test_new = X_test.drop('Feature 1',axis = 1)

# %%
y_pred = xg2.predict(X_test_new)

# %%
y_pred = y_pred*(X_test['Feature 1'])

# %%
bin2 = {}

bin2['Mean Absolute Error:'] =  metrics.mean_absolute_error(y_test, y_pred)  
bin2['Mean Squared Error:'] =  metrics.mean_squared_error(y_test, y_pred) 
bin2['Root Mean Squared Error:'] = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
bin2
# Out:
# {'Mean Absolute Error:': 163.22832606368402,
#  'Mean Squared Error:': 52130.639359715184,
#  'Root Mean Squared Error:': 228.3213510815736}

# %%
test_data_bin_2 = test_data.loc[test_data['bin'] == 2]
test_data_bin_2_input = test_data_bin_2[col]

# %%
test_data_bin_2_input
# Out:
#        Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 0           0.80          0          0          0          1          0  \
# 1           0.56          0          0          1          0          0
# 6           0.70          0          0          0          1          0
# 13          0.70          0          0          0          1          0
# 18          0.71          0          0          0          0          1
# ...          ...        ...        ...        ...        ...        ...
# 58064       0.78          0          0          0          0          1
# 58066       0.52          0          0          0          1          0
# 58067       1.00          0          0          1          0          0
# 58068       0.73          0          0          1          0          0
# 58071       0.71          0          0          1          0          0
#
#        Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 17
# ...

# %%
train_data_bin_2_target_new = train_data_bin_2_target/train_data_bin_2_input['Feature 1']
train_data_bin_2_input_new  = train_data_bin_2_input.drop('Feature 1',axis = 1)

# %%
xg2.fit(train_data_bin_2_input_new,train_data_bin_2_target_new)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_data_bin_2_input_new = test_data_bin_2_input.drop('Feature 1',axis = 1)

# %%
test_pred_bin_2 = xg2.predict(test_data_bin_2_input_new)

# %%
test_pred_bin_2_new = test_pred_bin_2*(test_data_bin_2_input['Feature 1'])

# %%
price_pred_bin_2 = pd.DataFrame({'id': test_data_bin_2.id, 'Price': test_pred_bin_2_new})

# %%
xg3 = XGBRegressor(n_estimators=500, learning_rate=0.02,subsample = 0.4)

# %%
train_data_bin_3 = train_data.loc[train_data['bin'] == 3]
train_data_bin_3_input = train_data_bin_3[col]
train_data_bin_3_target = train_data_bin_3['price']

# %%
X_train ,X_test,y_train,y_test = train_test_split(train_data_bin_3_input,train_data_bin_3_target, test_size=0.2, random_state=42)

# %%
xg3.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.02, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = xg3.predict(X_test)

# %%
bin3 = {}

bin3['Mean Absolute Error:'] =  metrics.mean_absolute_error(y_test, y_pred)  
bin3['Mean Squared Error:'] =  metrics.mean_squared_error(y_test, y_pred) 
bin3['Root Mean Squared Error:'] = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
bin3
# Out:
# {'Mean Absolute Error:': 638.9900601868446,
#  'Mean Squared Error:': 908052.7364517531,
#  'Root Mean Squared Error:': 952.9180114006415}

# %%
test_data_bin_3 = test_data.loc[test_data['bin'] == 3]
test_data_bin_3_input = test_data_bin_3[col]

# %%
train_data_bin_3_target_new = train_data_bin_3_target/train_data_bin_3_input['Feature 1']
train_data_bin_3_input_new  = train_data_bin_3_input.drop('Feature 1',axis = 1)

# %%
train_data_bin_3_input
# Out:
#         Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 2            2.03          0          0          1          0          0  \
# 5            1.39          0          0          1          0          0
# 14           1.00          0          0          0          0          1
# 16           1.07          0          0          0          0          1
# 23           1.33          0          0          0          0          1
# ...           ...        ...        ...        ...        ...        ...
# 135476       1.59          0          0          0          1          0
# 135486       2.02          0          0          0          1          0
# 135491       1.11          0          0          0          1          0
# 135498       2.03          0          0          0          1          0
# 135500       1.72          0          0          1          0          0
#
#         Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 17
# ...

# %%
xg3.fit(train_data_bin_3_input_new,train_data_bin_3_target_new)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.02, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_data_bin_3_input_new = test_data_bin_3_input.drop('Feature 1',axis = 1)

# %%
test_pred_bin_3 = xg3.predict(test_data_bin_3_input_new)

# %%
test_pred_bin_3_new = test_pred_bin_3*(test_data_bin_3_input['Feature 1'])

# %%
price_pred_bin_3 = pd.DataFrame({'id': test_data_bin_3.id, 'Price': test_pred_bin_3_new})

# %%
temp = pd.concat([price_pred_bin_1,price_pred_bin_2])

# %%
final = pd.concat([temp,price_pred_bin_3])

# %%
final.to_csv('./Results/Result17.csv')
