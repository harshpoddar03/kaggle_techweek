# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import pickle

# %%
train_data_input = pd.read_csv(r'Data\traininput.csv')
targetvariable = pd.read_csv(r'Data\targetvariable.csv')

# %%
train_data_input
# Out:
#         Unnamed: 0      id  Feature 1  Feature 7  Feature 8  Feature 9
# 0                0  143728   0.100000          0          1          0  \
# 1                1   52657   0.090909          0          0          0
# 2                2  124407   0.554545          0          0          0
# 3                3   45535   0.039394          0          1          0
# 4                4  178894   0.212121          0          0          0
# ...            ...     ...        ...        ...        ...        ...
# 135496      135496   34345   0.151515          1          0          0
# 135497      135497    9899   0.039394          0          0          0
# 135498      135498  142454   0.554545          0          0          0
# 135499      135499  129168   0.160606          0          1          0
# 135500      135500   10470   0.460606          0          1          0
#
#         Feature 10  Feature 12  Feature 13  Feature 14  Feature 16
# ...

# %%
train_data_input = train_data_input.drop('Unnamed: 0',axis = 1)
targetvariable = targetvariable.drop('Unnamed: 0',axis = 1)

# %%
train_data_input
# Out:
#             id  Feature 1  Feature 7  Feature 8  Feature 9  Feature 10
# 0       143728   0.100000          0          1          0           0  \
# 1        52657   0.090909          0          0          0           0
# 2       124407   0.554545          0          0          0           1
# 3        45535   0.039394          0          1          0           0
# 4       178894   0.212121          0          0          0           0
# ...        ...        ...        ...        ...        ...         ...
# 135496   34345   0.151515          1          0          0           0
# 135497    9899   0.039394          0          0          0           0
# 135498  142454   0.554545          0          0          0           0
# 135499  129168   0.160606          0          1          0           0
# 135500   10470   0.460606          0          1          0           0
#
#         Feature 12  Feature 13  Feature 14  Feature 16  Feature 17
# ...

# %%
rf = RandomForestRegressor(n_estimators = 50, max_features = 0.8 , max_depth = 15, random_state = 18)

# %%
X_train ,X_test,y_train,y_test = train_test_split(train_data_input,targetvariable, test_size=0.2, random_state=42)

# %%
y_train
# Out:
#          price
# 91089    853.0
# 44923   9078.0
# 134431  4118.0
# 2180     787.0
# 45339   2617.0
# ...        ...
# 110268   906.0
# 119879   526.0
# 103694  9495.0
# 131932   756.0
# 121958  6906.0
#
# [108400 rows x 1 columns]

# %%
rf.fit(X_train, y_train)
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_5708\2725846524.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# RandomForestRegressor(max_depth=20, max_features=0.8, n_estimators=50,
#                       random_state=18)

# %%
y_pred = rf.predict(X_test)

# %%
with_burata = {}

with_burata['Mean Absolute Error:'] =  metrics.mean_absolute_error(y_test, y_pred)  
with_burata['Mean Squared Error:'] =  metrics.mean_squared_error(y_test, y_pred) 
with_burata['Root Mean Squared Error:'] = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
with_burata
# Out:
# {'Mean Absolute Error:': 362.63837236390503,
#  'Mean Squared Error:': 473451.71293673257,
#  'Root Mean Squared Error:': 688.0782752977545}

# %%
rf.fit(train_data_input,targetvariable)
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_5708\3203439712.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(train_data_input,targetvariable)
# RandomForestRegressor(max_depth=15, max_features=0.8, n_estimators=50,
#                       random_state=18)

# %%
test_data = pd.read_csv(r'Data\normalisedtest.csv')
test_data = test_data.drop('Unnamed: 0',axis = 1)

# %%
test_data
# Out:
#            id  Feature 1  Feature 7  Feature 8  Feature 9  Feature 10
# 0      132523   0.181818          0          0          1           0  \
# 1       70210   0.109091          0          1          0           0
# 2       93051   0.245455          0          0          0           0
# 3       67325   0.030303          0          0          0           0
# 4      189522   0.009091          0          1          0           0
# ...       ...        ...        ...        ...        ...         ...
# 58067   51474   0.242424          1          0          0           0
# 58068   50296   0.160606          0          1          0           0
# 58069   95077   0.272727          0          0          0           0
# 58070   71500   0.215152          0          1          0           0
# 58071  114675   0.154545          0          0          1           0
#
#        Feature 12  Feature 13  Feature 14  Feature 16  Feature 17  Feature 22
# ...

# %%
test_data_input = test_data.drop('price',axis = 1)

# %%
price_pred = rf.predict(test_data_input)

# %%
price_pred = pd.DataFrame({'id': test_data.id, 'Price': price_pred})

# %%
price_pred.to_csv('./Results/Result9.csv')
