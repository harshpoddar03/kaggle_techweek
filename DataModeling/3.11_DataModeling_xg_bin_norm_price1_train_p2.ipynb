# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv(r"Data\train_data_binned_price3.csv")
test_data = pd.read_csv(r"Data\test_data_binned_price3.csv")

# %%
train_data.min()
# Out:
# Unnamed: 0         0.000000
# id                 0.000000
# Feature 1          0.200000
# Feature 2          0.000000
# Feature 3          0.000000
# Feature 4          0.000000
# Feature 5          0.000000
# Feature 6          0.000000
# Feature 7          0.000000
# Feature 8          0.000000
# Feature 9          0.000000
# Feature 10         0.000000
# Feature 11         0.000000
# Feature 12         0.000000
# Feature 13         0.000000
# Feature 14         0.000000
# Feature 15         0.000000
# Feature 16         0.000000
# Feature 17         0.000000
# Feature 18         0.000000
# Feature 19         0.000000
# Feature 20         0.000000
# Feature 21         0.000000
# Feature 22        52.700000
# Feature 23        51.000000
# Feature  24        0.000000
# Feature 25         0.000000
# Feature 26         0.000000
# price            326.000000
# price2           938.095238
# price3          1715.594864
# Feature 26.1       0.000000
# Feature 24.1       0.000000
# Feature 25.1       0.000000
# bin                1.000000
# dtype: float64

# %%
col = list(train_data.columns)
col.remove('Unnamed: 0')
#col.remove('Unnamed: 0.1')
#col.remove('Unnamed: 0.2')
col.remove('id')
col.remove('price')
col.remove('price2')
col.remove('price3')
col.remove('bin')
#col.remove('Feature 2')
#col.remove('Feature 3')
#col.remove('Feature 4')
#col.remove('Feature 5')
#col.remove('Feature 6')
#col.remove('Feature 11')
#col.remove('Feature 15')
#col.remove('Feature 18')
#col.remove('Feature 19')
#col.remove('Feature 20')
#col.remove('Feature 21')
col
# Out:
# ['Feature 1',
#  'Feature 2',
#  'Feature 3',
#  'Feature 4',
#  'Feature 5',
#  'Feature 6',
#  'Feature 7',
#  'Feature 8',
#  'Feature 9',
#  'Feature 10',
#  'Feature 11',
#  'Feature 12',
#  'Feature 13',
#  'Feature 14',
#  'Feature 15',
#  'Feature 16',
#  'Feature 17',
#  'Feature 18',
#  'Feature 19',
#  'Feature 20',
#  'Feature 21',
#  'Feature 22',
#  'Feature 23',
#  'Feature  24',
#  'Feature 25',
#  'Feature 26',
#  'Feature 26.1',
#  'Feature 24.1',
#  'Feature 25.1']

# %%
train_data['train-test'] = "train"
test_data['train-test'] = "test"

# %%
combined_df = pd.concat([train_data,test_data]).fillna('TBC')

# %%
scaler = MinMaxScaler()

#combined_df["Feature 1"] = scaler.fit_transform(np.array(combined_df["Feature 1"]).reshape(-1,1))
combined_df["Feature 22"] = scaler.fit_transform(np.array(combined_df["Feature 22"]).reshape(-1,1))
combined_df["Feature 23"] = scaler.fit_transform(np.array(combined_df["Feature 23"]).reshape(-1,1))
combined_df["Feature  24"] = scaler.fit_transform(np.array(combined_df["Feature  24"]).reshape(-1,1))
combined_df["Feature 25"] = scaler.fit_transform(np.array(combined_df["Feature 25"]).reshape(-1,1))
combined_df["Feature 26"] = scaler.fit_transform(np.array(combined_df["Feature 26"]).reshape(-1,1))
combined_df["Feature 24.1"] = scaler.fit_transform(np.array(combined_df["Feature  24"]).reshape(-1,1))
combined_df["Feature 25.1"] = scaler.fit_transform(np.array(combined_df["Feature 25"]).reshape(-1,1))
combined_df["Feature 26.1"] = scaler.fit_transform(np.array(combined_df["Feature 26"]).reshape(-1,1))

# %%
df_group = combined_df.groupby(['train-test'])
train_data = df_group.get_group('train')
test_data = df_group.get_group('test')

# %%
train_data.min()
# Out:
# Unnamed: 0                0
# id                        0
# Feature 1               0.2
# Feature 2                 0
# Feature 3                 0
# Feature 4                 0
# Feature 5                 0
# Feature 6                 0
# Feature 7                 0
# Feature 8                 0
# Feature 9                 0
# Feature 10                0
# Feature 11                0
# Feature 12                0
# Feature 13                0
# Feature 14                0
# Feature 15                0
# Feature 16                0
# Feature 17                0
# Feature 18                0
# Feature 19                0
# Feature 20                0
# Feature 21                0
# Feature 22         0.030769
# Feature 23         0.066667
# Feature  24             0.0
# Feature 25              0.0
# Feature 26              0.0
# price                 326.0
# price2           938.095238
# price3          1715.594864
# Feature 26.1            0.0
# Feature 24.1            0.0
# Feature 25.1            0.0
# bin                       1
# train-test            train
# dtype: object

# %%
train_data = train_data.drop('train-test',axis=1)
test_data = test_data.drop('train-test',axis=1)

# %%
test_data = test_data.drop('price',axis = 1)

# %%
test_data
# Out:
#        Unnamed: 0      id  Feature 1  Feature 2  Feature 3  Feature 4
# 0          132523  132523       0.80          0          0          0  \
# 1           70210   70210       0.56          0          0          1
# 2           93051   93051       1.01          0          0          0
# 3           67325   67325       0.30          0          0          0
# 4          189522  189522       0.23          0          0          0
# ...           ...     ...        ...        ...        ...        ...
# 58067       51474   51474       1.00          0          0          1
# 58068       50296   50296       0.73          0          0          1
# 58069       95077   95077       1.10          0          0          0
# 58070       71500   71500       0.91          0          0          0
# 58071      114675  114675       0.71          0          0          1
#
#        Feature 5  Feature 6  Feature 7  Feature 8  ...  Feature 23
# 0              1          0          0          0  ...    0.333333  \
# 1              0          0          0          1  ...    0.166667
# 2              1          0          0          0  ...    0.433333
# 3              0          1          0          0  ...    0.300000
# 4              1          0          0          1  ...    0.300000
# ...          ...        ...        ...        ...  ...         ...
# 58067          0          0          1          0  ...    0.233333
# 58068          0          0          0          1  ...    0.266667
# 58069          1          0          0          0  ...    0.300000
# 58070          1          0          0          1  ...    0.366667
# 58071          0          0          0          0  ...    0.233333
#
#        Feature  24  Feature 25  Feature 26  price2  price3  Feature 26.1
# 0         0.635121    0.598402    0.115335     TBC     TBC      0.115335  \
# 1         0.558360    0.527473    0.104792     TBC     TBC      0.104792
# 2         0.672976    0.634366    0.125240     TBC     TBC      0.125240
# 3         0.447950    0.429570    0.085942     TBC     TBC      0.085942
# 4         0.416404    0.397602    0.078914     TBC     TBC      0.078914
# ...            ...         ...         ...     ...     ...           ...
# 58067     0.666667    0.647353    0.126518     TBC     TBC      0.126518
# 58068     0.603575    0.576424    0.114377     TBC     TBC      0.114377
# 58069     0.692955    0.653347    0.130351     TBC     TBC      0.130351
# 58070     0.675079    0.634366    0.118530     TBC     TBC      0.118530
# 58071     0.603575    0.576424    0.111502     TBC     TBC      0.111502
#
#        Feature 24.1  Feature 25.1  bin
# 0          0.635121      0.598402    2
# 1          0.558360      0.527473    1
# 2          0.672976      0.634366    1
# 3          0.447950      0.429570    3
# 4          0.416404      0.397602    3
# ...             ...           ...  ...
# 58067      0.666667      0.647353    1
# 58068      0.603575      0.576424    2
# 58069      0.692955      0.653347    1
# 58070      0.675079      0.634366    2
# 58071      0.603575      0.576424    1
#
# [58072 rows x 34 columns]

# %%
from xgboost import XGBRegressor

# %%
xg = XGBRegressor(n_estimators=300, learning_rate=0.05,subsample = 0.75)

# %%
train_data_bin_1 = train_data.loc[train_data['bin'] == 1]
train_data_bin_1_input = train_data_bin_1[col]
train_data_bin_1_target = train_data_bin_1['price2']

# %%
train_data_bin_1_input
# Out:
#         Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 1            0.50          0          1          0          0          0  \
# 2            2.03          0          0          1          0          0
# 4            0.90          0          1          0          0          0
# 6            1.00          0          0          0          1          0
# 15           0.31          0          0          1          0          0
# ...           ...        ...        ...        ...        ...        ...
# 135344       2.02          0          0          0          1          0
# 135348       0.87          0          0          0          0          1
# 135349       1.11          0          0          0          1          0
# 135350       0.71          0          0          1          0          0
# 135356       2.03          0          0          0          1          0
#
#         Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 20
# 1               0          0          0           0  ...           0  \
# 2               0          0          0           1  ...           0
# 4               0          0          0           0  ...           0
# 6               0          0          0           0  ...           0
# 15              0          0          0           0  ...           0
# ...           ...        ...        ...         ...  ...         ...
# 135344          0          0          0           0  ...           0
# 135348          0          0          0           0  ...           0
# 135349          0          0          0           0  ...           0
# 135350          0          0          0           0  ...           0
# 135356          0          0          0           0  ...           0
#
#         Feature 21  Feature 22  Feature 23  Feature  24  Feature 25
# 1                0    0.600000    0.233333     0.514196    0.501499  \
# 2                0    0.364103    0.366667     0.882229    0.828172
# 4                0    0.589744    0.333333     0.635121    0.607393
# 6                0    0.420513    0.333333     0.677182    0.650350
# 15               0    0.441026    0.233333     0.456362    0.436563
# ...            ...         ...         ...          ...         ...
# 135344           0    0.543590    0.233333     0.848580    0.799201
# 135348           0    0.574359    0.233333     0.638275    0.610390
# 135349           0    0.558974    0.300000     0.698212    0.667333
# 135350           0    0.456410    0.266667     0.605678    0.580420
# 135356           0    0.389744    0.333333     0.881178    0.829171
#
#         Feature 26  Feature 26.1  Feature 24.1  Feature 25.1
# 1         0.101597      0.101597      0.514196      0.501499
# 2         0.157827      0.157827      0.882229      0.828172
# 4         0.123323      0.123323      0.635121      0.607393
# 6         0.124281      0.124281      0.677182      0.650350
# 15        0.084345      0.084345      0.456362      0.436563
# ...            ...           ...           ...           ...
# 135344    0.160703      0.160703      0.848580      0.799201
# 135348    0.123323      0.123323      0.638275      0.610390
# 135349    0.134505      0.134505      0.698212      0.667333
# 135350    0.113099      0.113099      0.605678      0.580420
# 135356    0.158786      0.158786      0.881178      0.829171
#
# [45719 rows x 29 columns]

# %%
train_data_bin_1_input.min()
# Out:
# Feature 1       0.280000
# Feature 2       0.000000
# Feature 3       0.000000
# Feature 4       0.000000
# Feature 5       0.000000
# Feature 6       0.000000
# Feature 7       0.000000
# Feature 8       0.000000
# Feature 9       0.000000
# Feature 10      0.000000
# Feature 11      0.000000
# Feature 12      0.000000
# Feature 13      0.000000
# Feature 14      0.000000
# Feature 15      0.000000
# Feature 16      0.000000
# Feature 17      0.000000
# Feature 18      0.000000
# Feature 19      0.000000
# Feature 20      0.000000
# Feature 21      0.000000
# Feature 22      0.051282
# Feature 23      0.066667
# Feature  24     0.000000
# Feature 25      0.000000
# Feature 26      0.000000
# Feature 26.1    0.000000
# Feature 24.1    0.000000
# Feature 25.1    0.000000
# dtype: float64

# %%
X_train ,X_test,y_train,y_test = train_test_split(train_data_bin_1_input,train_data_bin_1_target, test_size=0.2, random_state=42)

# %%
X_train.min()
# Out:
# Feature 1       0.280000
# Feature 2       0.000000
# Feature 3       0.000000
# Feature 4       0.000000
# Feature 5       0.000000
# Feature 6       0.000000
# Feature 7       0.000000
# Feature 8       0.000000
# Feature 9       0.000000
# Feature 10      0.000000
# Feature 11      0.000000
# Feature 12      0.000000
# Feature 13      0.000000
# Feature 14      0.000000
# Feature 15      0.000000
# Feature 16      0.000000
# Feature 17      0.000000
# Feature 18      0.000000
# Feature 19      0.000000
# Feature 20      0.000000
# Feature 21      0.000000
# Feature 22      0.051282
# Feature 23      0.066667
# Feature  24     0.000000
# Feature 25      0.000000
# Feature 26      0.000000
# Feature 26.1    0.000000
# Feature 24.1    0.000000
# Feature 25.1    0.000000
# dtype: float64

# %%
xg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = xg.predict(X_test)

# %%
temp = X_test['Feature 1']
y_pred =  y_pred * temp.apply(lambda x : x) 
y_test =  y_test * temp.apply(lambda x : x)

# %%
X_test
# Out:
#         Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 12323        0.70          0          0          0          0          1  \
# 76556        2.05          0          0          0          1          0
# 48692        1.54          0          0          1          0          0
# 102322       0.32          0          0          1          0          0
# 48576        1.60          0          0          1          0          0
# ...           ...        ...        ...        ...        ...        ...
# 12959        1.52          0          0          0          1          0
# 34572        0.34          0          0          0          0          1
# 90213        1.15          0          0          1          0          0
# 39914        0.40          0          0          0          0          1
# 10861        1.16          0          1          0          0          0
#
#         Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 20
# 12323           0          0          0           1  ...           0  \
# 76556           0          0          0           0  ...           0
# 48692           0          0          0           0  ...           0
# 102322          0          0          0           1  ...           0
# 48576           0          0          0           0  ...           0
# ...           ...        ...        ...         ...  ...         ...
# 12959           0          0          0           1  ...           0
# 34572           0          0          0           0  ...           0
# 90213           0          0          0           0  ...           0
# 39914           0          0          1           0  ...           0
# 10861           0          0          0           0  ...           0
#
#         Feature 21  Feature 22  Feature 23  Feature  24  Feature 25
# 12323            0    0.415385    0.300000     0.603575    0.577423  \
# 76556            0    0.492308    0.233333     0.858044    0.811189
# 48692            0    0.533333    0.233333     0.781283    0.733267
# 102322           0    0.507692    0.233333     0.457413    0.436563
# 48576            0    0.482051    0.200000     0.792850    0.759241
# ...            ...         ...         ...          ...         ...
# 12959            0    0.466667    0.300000     0.773922    0.738262
# 34572            0    0.564103    0.233333     0.467928    0.445554
# 90213            0    0.507692    0.233333     0.711882    0.665335
# 39914            0    0.523077    0.233333     0.495268    0.475524
# 10861            0    0.466667    0.533333     0.709779    0.667333
#
#         Feature 26  Feature 26.1  Feature 24.1  Feature 25.1
# 12323     0.110863      0.110863      0.603575      0.577423
# 76556     0.160383      0.160383      0.858044      0.811189
# 48692     0.146965      0.146965      0.781283      0.733267
# 102322    0.086262      0.086262      0.457413      0.436563
# 48576     0.148243      0.148243      0.792850      0.759241
# ...            ...           ...           ...           ...
# 12959     0.144409      0.144409      0.773922      0.738262
# 34572     0.089776      0.089776      0.467928      0.445554
# 90213     0.133227      0.133227      0.711882      0.665335
# 39914     0.093930      0.093930      0.495268      0.475524
# 10861     0.131310      0.131310      0.709779      0.667333
#
# [9144 rows x 29 columns]

# %%
temp
# Out:
# 12323     0.70
# 76556     2.05
# 48692     1.54
# 102322    0.32
# 48576     1.60
#           ...
# 12959     1.52
# 34572     0.34
# 90213     1.15
# 39914     0.40
# 10861     1.16
# Name: Feature 1, Length: 9144, dtype: float64

# %%
y_test
# Out:
# 12323      2117.0
# 76556     18426.0
# 48692      6547.0
# 102322      477.0
# 48576      9698.0
#            ...
# 12959      8852.0
# 34572       538.0
# 90213      5805.0
# 39914       716.0
# 10861      4456.0
# Length: 9144, dtype: object

# %%
y_pred
# Out:
# 12323      2116.637646
# 76556     17429.108008
# 48692      8001.315137
# 102322      460.254180
# 48576      9022.454687
#               ...
# 12959      9969.156758
# 34572       492.762266
# 90213      5720.399292
# 39914       716.884277
# 10861      4540.263223
# Name: Feature 1, Length: 9144, dtype: float64

# %%
bin1 = {}

bin1['Mean Absolute Error:'] =  metrics.mean_absolute_error(y_test, y_pred)  
bin1['Mean Squared Error:'] =  metrics.mean_squared_error(y_test, y_pred) 
bin1['Root Mean Squared Error:'] = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
bin1
# Out:
# {'Mean Absolute Error:': 390.1713475543913,
#  'Mean Squared Error:': 478375.7306927041,
#  'Root Mean Squared Error:': 691.6471142806164}

# %%
test_data_bin_1 = test_data.loc[test_data['bin'] == 1]
test_data_bin_1_input = test_data_bin_1[col]

# %%
xg.fit(train_data_bin_1_input, train_data_bin_1_target)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_data_bin_1_input
# Out:
#        Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 3           0.30          0          0          0          0          1  \
# 4           0.23          0          0          0          1          0
# 5           0.30          0          0          1          0          0
# 8           0.42          0          0          1          0          0
# 11          0.32          0          0          0          1          0
# ...          ...        ...        ...        ...        ...        ...
# 58051       0.42          0          0          0          0          1
# 58053       0.30          0          0          1          0          0
# 58056       0.32          0          0          1          0          0
# 58060       0.31          0          0          1          0          0
# 58063       0.30          0          0          1          0          0
#
#        Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 17
# 3              0          0          0           0  ...           0  \
# 4              0          1          0           0  ...           0
# 5              0          0          0           1  ...           0
# 8              1          0          0           0  ...           0
# 11             1          0          0           0  ...           0
# ...          ...        ...        ...         ...  ...         ...
# 58051          1          0          0           0  ...           0
# 58053          0          0          0           1  ...           0
# 58056          0          1          0           0  ...           0
# 58060          0          1          0           0  ...           0
# 58063          0          0          0           1  ...           0
#
#        Feature 18  Feature 19  Feature 20  Feature 21  Feature 22  Feature 23
# 3               0           0           1           0    0.553846    0.300000  \
# 4               0           0           0           1    0.528205    0.300000
# 5               1           0           0           0    0.487179    0.266667
# 8               0           1           0           0    0.502564    0.233333
# 11              0           0           0           0    0.476923    0.333333
# ...           ...         ...         ...         ...         ...         ...
# 58051           0           0           0           0    0.461538    0.233333
# 58053           0           0           0           0    0.487179    0.266667
# 58056           0           1           0           0    0.461538    0.233333
# 58060           1           0           0           0    0.482051    0.200000
# 58063           0           0           0           1    0.517949    0.233333
#
#        Feature  24  Feature 25  Feature 26
# 3         0.447950    0.429570    0.085942
# 4         0.416404    0.397602    0.078914
# 5         0.454259    0.429570    0.084665
# 8         0.505783    0.477522    0.094888
# 11        0.459516    0.442557    0.086262
# ...            ...         ...         ...
# 58051     0.506835    0.485514    0.094249
# 58053     0.452156    0.432567    0.084984
# 58056     0.466877    0.438561    0.086262
# 58060     0.461619    0.435564    0.085942
# 58063     0.449001    0.428571    0.084984
#
# [19458 rows x 26 columns]

# %%
test_pred_bin_1 = xg.predict(test_data_bin_1_input)

# %%
test_pred_bin_1
# Out:
# array([2220.5752, 2253.2546, 2328.7668, ..., 2702.491 , 2695.4229,
#        2409.6377], dtype=float32)

# %%
temp = test_data_bin_1_input['Feature 1']
test_pred_bin_1=  test_pred_bin_1 * temp.apply(lambda x : x)

# %%
test_pred_bin_1
# Out:
# 3         666.172559
# 4         518.248567
# 5         698.630054
# 8        1050.353145
# 11        649.159336
#             ...
# 58051     841.388687
# 58053     868.571851
# 58056     864.797109
# 58060     835.581084
# 58063     722.891309
# Name: Feature 1, Length: 19458, dtype: float64

# %%
price_pred_bin_1 = pd.DataFrame({'id': test_data_bin_1.id, 'Price': test_pred_bin_1})

# %%
xg2 = XGBRegressor(n_estimators=300, learning_rate=0.05,subsample = 0.75)

# %%
train_data_bin_2 = train_data.loc[train_data['bin'] == 2]
train_data_bin_2_input = train_data_bin_2[col]
train_data_bin_2_target = train_data_bin_2['price2']

# %%
X_train ,X_test,y_train,y_test = train_test_split(train_data_bin_2_input,train_data_bin_2_target, test_size=0.2, random_state=42)

# %%
xg2.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = xg2.predict(X_test)

# %%
temp = X_test['Feature 1']
y_pred =  y_pred * temp.apply(lambda x : x) 
y_test =  y_test * temp.apply(lambda x : x)

# %%
bin2 = {}

bin2['Mean Absolute Error:'] =  metrics.mean_absolute_error(y_test, y_pred)  
bin2['Mean Squared Error:'] =  metrics.mean_squared_error(y_test, y_pred) 
bin2['Root Mean Squared Error:'] = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
bin2
# Out:
# {'Mean Absolute Error:': 164.349288093813,
#  'Mean Squared Error:': 83195.09133620953,
#  'Root Mean Squared Error:': 288.43559304671385}

# %%
test_data_bin_2 = test_data.loc[test_data['bin'] == 2]
test_data_bin_2_input = test_data_bin_2[col]

# %%
xg2.fit(train_data_bin_2_input, train_data_bin_2_target)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_data_bin_2_input
# Out:
#        Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 0           0.80          0          0          0          1          0  \
# 1           0.56          0          0          1          0          0
# 6           0.70          0          0          0          1          0
# 13          0.70          0          0          0          1          0
# 18          0.71          0          0          0          0          1
# ...          ...        ...        ...        ...        ...        ...
# 58064       0.78          0          0          0          0          1
# 58066       0.52          0          0          0          1          0
# 58067       1.00          0          0          1          0          0
# 58068       0.73          0          0          1          0          0
# 58071       0.71          0          0          1          0          0
#
#        Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 17
# 0              0          0          1           0  ...           0  \
# 1              0          1          0           0  ...           1
# 6              0          0          0           0  ...           0
# 13             0          0          0           0  ...           0
# 18             0          0          1           0  ...           1
# ...          ...        ...        ...         ...  ...         ...
# 58064          0          0          1           0  ...           1
# 58066          1          0          0           0  ...           0
# 58067          1          0          0           0  ...           1
# 58068          0          1          0           0  ...           0
# 58071          0          0          1           0  ...           1
#
#        Feature 18  Feature 19  Feature 20  Feature 21  Feature 22  Feature 23
# 0               0           0           0           0    0.410256    0.333333  \
# 1               0           0           0           0    0.512821    0.166667
# 6               0           1           0           0    0.548718    0.333333
# 13              1           0           0           0    0.400000    0.300000
# 18              0           0           0           0    0.482051    0.300000
# ...           ...         ...         ...         ...         ...         ...
# 58064           0           0           0           0    0.600000    0.266667
# 58066           0           0           0           0    0.435897    0.366667
# 58067           0           0           0           0    0.497436    0.233333
# 58068           0           0           0           0    0.512821    0.266667
# 58071           0           0           0           0    0.435897    0.233333
#
#        Feature  24  Feature 25  Feature 26
# 0         0.625907    0.598402    0.115335
# 1         0.550259    0.527473    0.104792
# 6         0.588601    0.565435    0.113419
# 13        0.604145    0.579421    0.111502
# 18        0.584456    0.567433    0.111821
# ...            ...         ...         ...
# 58064     0.603109    0.585415    0.119169
# 58066     0.537824    0.523477    0.100958
# 58067     0.656995    0.647353    0.126518
# 58068     0.594819    0.576424    0.114377
# 58071     0.594819    0.576424    0.111502
#
# [20119 rows x 26 columns]

# %%
test_pred_bin_2 = xg2.predict(test_data_bin_2_input)

# %%
temp = test_data_bin_2_input['Feature 1']
test_pred_bin_2=  test_pred_bin_2 * temp.apply(lambda x : x)

# %%
price_pred_bin_2 = pd.DataFrame({'id': test_data_bin_2.id, 'Price': test_pred_bin_2})

# %%
xg3 = XGBRegressor(n_estimators=300, learning_rate=0.05,subsample = 0.75)

# %%
train_data_bin_3 = train_data.loc[train_data['bin'] == 3]
train_data_bin_3_input = train_data_bin_3[col]
train_data_bin_3_target = train_data_bin_3['price2']

# %%
X_train ,X_test,y_train,y_test = train_test_split(train_data_bin_3_input,train_data_bin_3_target, test_size=0.2, random_state=42)

# %%
xg3.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = xg3.predict(X_test)

# %%
temp = X_test['Feature 1']
y_pred =  y_pred * temp.apply(lambda x : x) 
y_test =  y_test * temp.apply(lambda x : x)

# %%
bin3 = {}

bin3['Mean Absolute Error:'] =  metrics.mean_absolute_error(y_test, y_pred)  
bin3['Mean Squared Error:'] =  metrics.mean_squared_error(y_test, y_pred) 
bin3['Root Mean Squared Error:'] = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
bin3
# Out:
# {'Mean Absolute Error:': 146.58594235725195,
#  'Mean Squared Error:': 103864.68848022589,
#  'Root Mean Squared Error:': 322.2804500434767}

# %%
test_data_bin_3 = test_data.loc[test_data['bin'] == 3]
test_data_bin_3_input = test_data_bin_3[col]

# %%
train_data_bin_3_input
# Out:
#         Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6
# 2            2.03          0          0          1          0          0  \
# 5            1.39          0          0          1          0          0
# 14           1.00          0          0          0          0          1
# 16           1.07          0          0          0          0          1
# 23           1.33          0          0          0          0          1
# ...           ...        ...        ...        ...        ...        ...
# 135476       1.59          0          0          0          1          0
# 135486       2.02          0          0          0          1          0
# 135491       1.11          0          0          0          1          0
# 135498       2.03          0          0          0          1          0
# 135500       1.72          0          0          1          0          0
#
#         Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 17
# 2               0          0          0           1  ...           1  \
# 5               0          0          0           1  ...           0
# 14              0          1          0           0  ...           0
# 16              0          1          0           0  ...           1
# 23              0          0          0           1  ...           0
# ...           ...        ...        ...         ...  ...         ...
# 135476          0          0          1           0  ...           0
# 135486          0          0          0           0  ...           1
# 135491          0          0          0           0  ...           0
# 135498          0          0          0           0  ...           0
# 135500          0          1          0           0  ...           0
#
#         Feature 18  Feature 19  Feature 20  Feature 21  Feature 22
# 2                0           0           0           0    0.364103  \
# 5                0           0           0           1    0.476923
# 14               1           0           0           0    0.374359
# 16               0           0           0           0    0.548718
# 23               1           0           0           0    0.543590
# ...            ...         ...         ...         ...         ...
# 135476           0           0           0           0    0.523077
# 135486           0           0           0           0    0.543590
# 135491           0           1           0           0    0.558974
# 135498           0           1           0           0    0.389744
# 135500           0           0           0           0    0.466667
#
#         Feature 23  Feature  24  Feature 25  Feature 26
# 2         0.366667     0.869430    0.828172    0.157827
# 5         0.233333     0.749223    0.717283    0.141534
# 14        0.333333     0.670466    0.652348    0.123642
# 16        0.266667     0.676684    0.648352    0.130351
# 23        0.300000     0.721244    0.702298    0.139936
# ...            ...          ...         ...         ...
# 135476    0.333333     0.775130    0.744256    0.148562
# 135486    0.233333     0.836269    0.799201    0.160703
# 135491    0.300000     0.688083    0.667333    0.134505
# 135498    0.333333     0.868394    0.829171    0.158786
# 135500    0.266667     0.794819    0.771229    0.150479
#
# [43151 rows x 26 columns]

# %%
xg3.fit(train_data_bin_3_input,train_data_bin_3_target)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_pred_bin_3 = xg3.predict(test_data_bin_3_input)

# %%
temp = test_data_bin_3_input['Feature 1']
test_pred_bin_3 =  test_pred_bin_3 * temp.apply(lambda x : x)

# %%
price_pred_bin_3 = pd.DataFrame({'id': test_data_bin_3.id, 'Price': test_pred_bin_3})

# %%
temp = pd.concat([price_pred_bin_1,price_pred_bin_2])

# %%
final = pd.concat([temp,price_pred_bin_3])

# %%
final.to_csv('./Results/Result21_xg_norm_bin_price1_test_price2.csv',index=False)
